# %%
import pandas as pd
df = pd.read_csv('../lda-results/document_topic_with_lyrics_and_top_10.csv')
del df['Unnamed: 0']
df
# Out:
#         Topic 0: got, like, yeah, aint, dont, know, nigga, shit, want, man  \
# 0                                                   0.707
# 1                                                   0.203
# 2                                                   0.002
# 3                                                   0.736
# 4                                                   0.003
# ...                                                   ...
# 158675                                              0.910
# 158676                                              0.687
# 158677                                              0.758
# 158678                                              0.996
# 158679                                              0.691
#
#         Topic 1: life, world, like, god, away, eyes, light, time, come, theres  \
# 0                                                   0.001
# 1                                                   0.310
# ...

# %%
df.loc[df['artist'] == "Flo Milli"]
# Out:
#         Topic 0: got, like, yeah, aint, dont, know, nigga, shit, want, man  \
# 158416                                              0.767
# 158510                                              0.767
# 158589                                              0.767
# 158618                                              0.767
# 158674                                              0.897
# 158675                                              0.910
# 158676                                              0.687
# 158677                                              0.758
# 158678                                              0.996
# 158679                                              0.691
#
#         Topic 1: life, world, like, god, away, eyes, light, time, come, theres  \
# 158416                                              0.001
# 158510                                              0.001
# 158589                                              0.001
# ...

# %%
df.loc[df['artist'] == "Lilithzplug"]
# Out:
#         Topic 0: got, like, yeah, aint, dont, know, nigga, shit, want, man  \
# 158481                                              0.793
# 158520                                              0.793
# 158573                                              0.793
# 158631                                              0.793
# 158645                                              0.793
# 158649                                              0.793
# 158666                                              0.911
# 158667                                              0.002
# 158668                                              0.017
# 158669                                              0.173
# 158670                                              0.002
# 158671                                              0.242
# 158672                                              0.052
# 158673                                              0.122
#
# ...
