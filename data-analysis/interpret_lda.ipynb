# %%
import pandas as pd
df = pd.read_csv('lda-results/document_topic.csv')
df
# Out:
#         Unnamed: 0  Topic 0: pum, doo, dem, mari, boom  \
# 0                0                               0.000
# 1                1                               0.000
# 2                2                               0.001
# 3                3                               0.000
# 4                4                               0.111
# ...            ...                                 ...
# 158348      158348                               0.001
# 158349      158349                               0.001
# 158350      158350                               0.002
# 158351      158351                               0.001
# 158352      158352                               0.001
#
#         Topic 1: nigga, fuck, got, like, shit  \
# 0                                       0.715
# 1                                       0.082
# 2                                       0.173
# 3                                       0.237
# 4                                       0.001
# ...

# %%
df.iloc[0]
# Out:
# Unnamed: 0                                 0.000
# Topic 0: pum, doo, dem, mari, boom         0.000
# Topic 1: nigga, fuck, got, like, shit      0.715
# Topic 2: lord, good, ride, tonight, gon    0.000
# Topic 3: rock, got, new, like, work        0.000
# Topic 4: come, day, away, home, night      0.000
# Topic 5: love, dream, heart, song, sing    0.000
# Topic 6: blue, cri, fli, high, sky         0.000
# Topic 7: run, que, wild, ladi, devil       0.000
# Topic 8: like, just, onli, believ, make    0.000
# Topic 9: love, babi, want, know, let       0.117
# Topic 10: know, time, just, thi, say       0.090
# Topic 11: yeah, got, girl, like, gon       0.000
# Topic 12: thi, let, god, eye, soul         0.000
# Topic 13: world, live, life, hey, thi      0.074
# Topic 14: man, like, woman, got, gon       0.000
# dominant_topic                             1.000
# Name: 0, dtype: float64
