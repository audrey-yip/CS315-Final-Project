# %% [markdown]
# ### Retrieving Top Songs & Lyrics for Artist
# ####  @author: Jyontika Kapoor

# %%
# pip install spotipy
# pip install lxml

# %% [markdown]
# ### The below code uses the **spotipy** package to get the top tracks of an artist. Each artist has a spotify ID which we obtain using *sp.search()*. Then we get the top tracks through the *artist_top_tracks()* method.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import requests
import os
import pandas as pd
from bs4 import BeautifulSoup
# Out:
# /var/folders/94/hzlwrw5d571cgm5snsf618b00000gn/T/ipykernel_53677/1220656153.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
## CLIENT ID AND CLIENT SECRET
### DO NOT PUT ON GIT

client_id = ''
client_secret = ''
genius_access_token = 'lOqXN-Ms2yerxQ84trh3ex5sV_QehWhhQNG2BecI0n3DcCuqV2Cq-Sb9py7U7ETO'

# %%
def get_top_tracks(artist_name, client_id, client_secret):
    # Initialize Spotify client with your credentials
    credentials = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
    sp = spotipy.Spotify(client_credentials_manager=credentials)
    
    # search for the artist to get the Spotify ID through sp.search
    results = sp.search(q='artist:' + artist_name, type='artist') 
    items = results['artists']['items']
    if not items:
        return []
    
    
    artist_id = items[0]['id']
    
    top_tracks = sp.artist_top_tracks(artist_id)
    
    return [track['name'] for track in top_tracks['tracks']]

# %%
artist_name = 'Selena Gomez'
top_tracks = get_top_tracks(artist_name, client_id, client_secret)
top_tracks
# Out:
# ---------------------------------------------------------------------------
# SpotifyOauthError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 artist_name = 'Selena Gomez'
# ----> 2 top_tracks = get_top_tracks(artist_name, client_id, client_secret)
#       3 top_tracks
#
# Cell In[6], line 3, in get_top_tracks(artist_name, client_id, client_secret)
#       1 def get_top_tracks(artist_name, client_id, client_secret):
#       2     # Initialize Spotify client with your credentials
# ----> 3     credentials = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
#       4     sp = spotipy.Spotify(client_credentials_manager=credentials)
#       6     # search for the artist to get the Spotify ID through sp.search
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/oauth2.py:201, in SpotifyClientCredentials.__init__(self, client_id, client_secret, proxies, requests_session, requests_timeout, cache_handler)
#     172 """
#     173 Creates a Client Credentials Flow Manager.
#     174
#    (...)
#     196
#     197 """
#     199 super(SpotifyClientCredentials, self).__init__(requests_session)
# --> 201 self.client_id = client_id
#     202 self.client_secret = client_secret
#     203 self.proxies = proxies
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/oauth2.py:94, in SpotifyAuthBase.client_id(self, val)
#      92 @client_id.setter
#      93 def client_id(self, val):
# ---> 94     self._client_id = _ensure_value(val, "client_id")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/oauth2.py:70, in _ensure_value(value, env_key)
#      65 if _val is None:
#      66     msg = "No %s. Pass it or set a %s environment variable." % (
#      67         env_key,
#      68         env_val,
#      69     )
# ---> 70     raise SpotifyOauthError(msg)
#      71 return _val
#
# SpotifyOauthError: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.

# %% [markdown]
# #### Now we want to get the lyrics for each of the 10 tracks. We will do this using the **genius API** and the requests & bs4 library. The idea is we will search a song name on Genius through the requests library, find a match, and use bs4 to parse the HTML and extract the lyrics.

# %%
def get_lyrics(song_name, artist_name, genius_access_token):
    #set up the request using access token 
    base_url = "https://api.genius.com"
    headers = {'Authorization': 'Bearer ' + genius_access_token}
    search_url = base_url + "/search" #getting ready to search!
    data = {'q': song_name} #we want to search the song name!

    response = requests.get(search_url, params=data, headers=headers)
    json = response.json()
    path = None

    # loops through the search results returned by the Genius API to find a specific song that matches name of song and artist name

    for hit in json["response"]["hits"]:
        if artist_name.lower() in hit["result"]["primary_artist"]["name"].lower():
            path = hit["result"]["path"]
            break #assuming the first is right 

    if path:
        lyrics_url = "https://genius.com" + path
        lyrics_response = requests.get(lyrics_url)
        soup = BeautifulSoup(lyrics_response.text, 'lxml')

        # Check if the song is instrumental
        instrumental_div = soup.find('div', class_='LyricsPlaceholder__Message-uen8er-2')
        if instrumental_div:
            return "This song is an instrumental"

        lyrics_div = soup.find('div', {'data-lyrics-container': 'true'})
        lyrics = lyrics_div.get_text(separator='\n', strip=True) if lyrics_div else "Lyrics not found"
        return lyrics

    else:
        return "Lyrics not found"

# %%
artist_name = 'Kesha'
tracks = get_top_tracks(artist_name, client_id, client_secret)
tracks
# Out:
# ['Timber',
#  'TiK ToK',
#  'Right Round',
#  'Die Young',
#  'We R Who We R',
#  'Your Love Is My Drug',
#  'Good Old Days',
#  'Backstabber',
#  'Blow',
#  'Take It Off']

# %%
lyrics = get_lyrics(tracks[1], artist_name, genius_access_token)
print(lyrics)
# Out:
# [Verse 1]
# Wake up in the morning feelin' like P. Diddy
# (
# Hey, what up, girl?
# )
# Grab my glasses, I'm out the door, I'm gonna hit this city
# (
# Let's go
# )
# Before I leave, brush my teeth with a bottle of Jack
# 'Cause when I leave for the night, I ain't coming back
# [Pre-Chorus]
# I'm talkin' pedicure on our toes, toes, tryin' on all our clothes, clothes
# Boys blowin' up our phones, phones
# Drop-toppin', playin' our favorite CDs, pullin' up to the parties
# Tryna get a little bit tipsy
# [Chorus]
# Don't stop, make it pop, DJ, blow my speakers up
# Tonight, I'ma fight 'til we see the sunlight
# Tick tock on the clock, but the party don't stop, no
# Oh, woah, woah, oh, oh, woah, woah, oh
# Don't stop, make it pop, DJ, blow my speakers up
# Tonight, I'ma fight 'til we see the sunlight
# Tick tock on the clock, but the party don't stop, no
# Oh, woah, woah, oh, oh, woah, woah, oh
# [Verse 2]
# Ain't got a care in the world, but got plenty of beer
# Ain't got no money in my pocket, but I'm already here
# And now the dudes are linin' up, 'cause they hear we got swagger
# But we kick 'em to the curb unless they look like Mick Jagger

# %% [markdown]
# ### Now we will retrive lyrics from the identified viral songs

# %%
cwd = os.getcwd()
viral_songs = f'{cwd}/data-analysis/viral.csv'
viral_songs = pd.read_csv(viral_songs)
viral_songs
# Out:
#                                          artists  \
# 0                                  Kinfolk Thugs
# 1                                       Cordelia
# 2   ¥$, Kanye West, Ty Dolla $ign & Rich The Kid
# 3                                  Ariana Grande
# 4                                 Bobby Caldwell
# 5                                          R.m.y
# 6                                        Rihanna
# 7            The Weeknd, JENNIE & Lily Rose Depp
# 8                                     Gold-Tiger
# 9                                        Beyoncé
# 10                                  Masego & FKJ
# 11                                  Lana Del Rey
# 12                           Peso Pluma & Anitta
# 13                                     21 Savage
# 14                                       Beyoncé
# 15                                       Beyoncé
# 16                                     Flo Milli
# 17                                  Lana Del Rey
# 18                                     Muni Long
# 19                                  Lana Del Rey
# 20                                  Lana Del Rey
# 21                            ผดุง ทรงแสง (แจ๊ส)
# 22                                   Lilithzplug
# 23                                       Rihanna
# 24                                     Muni Long
# 25                                       Rihanna
# 26                                  Lana Del Rey
# 27                                  Lana Del Rey
# 28                                       Rihanna
# 29                                       Beyoncé
# 30                                  Lana Del Rey
# 31                                 Ariana Grande
# 32                                 Ariana Grande
#
#                                                 songs
# 0                                           Dumptruck
# 1                                         Little Life
# 2                      CARNIVAL (feat. Playboi Carti)
# 3                                   yes, and? (Mixed)
# 4                          What You Won't Do for Love
# 5                          How I Love Being a Woman 6
# 6                          Bitch Better Have My Money
# 7                                    One Of The Girls
# 8                                               Funny
# 9                                           Countdown
# 10                                              Tadow
# 11                            Every Man Gets His Wish
# 12                                           BELLAKEO
# 13                                     redrum (Mixed)
# 14                     TEXAS HOLD 'EM (PONY UP REMIX)
# 15                                               Donk
# 16                              Never Lose Me (Mixed)
# 17                                  Queen Of Disaster
# 18                                Made For Me (Mixed)
# 19                                    National Anthem
# 20                                         West Coast
# 21  หลวงพี่แจ๊ส 4G (From "ภาพยนตร์เรื่องหลวงพี่แจ๊...
# 22                                    CLEARED - Remix
# 23                We Found Love (feat. Calvin Harris)
# 24                      Made For Me (Sped Up Version)
# 25                   Work (feat. Drake) [R3hab Remix]
# 26                         Margaret (feat. Bleachers)
# 27                                 Back To The Basics
# 28                                         Pour It Up
# 29                              Dangerously in Love 2
# 30                                Young and Beautiful
# 31                                              34+35
# 32                                yes, and? (sped up)

# %%
from collections import Counter

singers = []
artists = Counter(viral_songs['artists'])
for artist in artists: 
    singers.append(artist)

singers
# Out:
# ['Kinfolk Thugs',
#  'Cordelia',
#  '¥$, Kanye West, Ty Dolla $ign & Rich The Kid',
#  'Ariana Grande',
#  'Bobby Caldwell',
#  'R.m.y',
#  'Rihanna',
#  'The Weeknd, JENNIE & Lily Rose Depp',
#  'Gold-Tiger',
#  'Beyoncé',
#  'Masego & FKJ',
#  'Lana Del Rey',
#  'Peso Pluma & Anitta',
#  '21 Savage',
#  'Flo Milli',
#  'Muni Long',
#  'ผดุง ทรงแสง (แจ๊ส)',
#  'Lilithzplug']

# %% [markdown]
# ### Add in Lyrics to our Data Frame

# %%
songs_data = pd.read_csv("/Users/jyontika/Documents/GitHub/CS315-Final-Project/test-shazam-api/songs_info.csv")

# %%
songs_data
# Out:
#                                 file_name  \
# 0    share_video_7309247847898090794_.mp3
# 1    share_video_7329274198096973099_.mp3
# 2    share_video_7339685917759769899_.mp3
# 3    share_video_7329990500528753953_.mp3
# 4    share_video_7324083003284573482_.mp3
# ..                                    ...
# 505  share_video_7331566337015237930_.mp3
# 506  share_video_7331565050198543659_.mp3
# 507  share_video_7341274575193378090_.mp3
# 508  share_video_7322305748975848705_.mp3
# 509  share_video_7338058289869081889_.mp3
#
#                                             track_name              artist  \
# 0                 TAKI TA TRIBALERO (feat. DJ Erandes)            DJ Mecca
# 1                             Montagem Mysterious Game              LXNGVX
# 2                                            Dumptruck       Kinfolk Thugs
# 3                                           Old Future       Koday Jackson
# 4                                          Little Life            Cordelia
# ..                                                 ...                 ...
# 505  หลวงพี่แจ๊ส 4G (From "ภาพยนตร์เรื่องหลวงพี่แจ๊...  ผดุง ทรงแสง (แจ๊ส)
# 506                                        Show Me How         Men I Trust
# 507                                yes, and? (sped up)       Ariana Grande
# 508                                              Funny          Gold-Tiger
# 509               Work from Home (feat. Ty Dolla $ign)       Fifth Harmony
#
#                                          track_subject
# 0      TAKI TA TRIBALERO (feat. DJ Erandes) - DJ Mecca
# 1                    Montagem Mysterious Game - LXNGVX
# 2                            Dumptruck - Kinfolk Thugs
# 3                           Old Future - Koday Jackson
# 4                               Little Life - Cordelia
# ..                                                 ...
# 505  หลวงพี่แจ๊ส 4G (From "ภาพยนตร์เรื่องหลวงพี่แจ๊...
# 506                          Show Me How - Men I Trust
# 507                yes, and? (sped up) - Ariana Grande
# 508                                 Funny - Gold-Tiger
# 509  Work from Home (feat. Ty Dolla $ign) - Fifth H...
#
# [510 rows x 4 columns]

# %%
songs_data.drop('track_subject', axis=1, inplace=True)

# %%
replacement_dict = {
    'yes, and? (sped up)': 'yes, and',
    'yes, and? (Mixed)': 'yes, and',
    'Made For Me (Sped Up Version)' : 'Made for Me',
    'Made For Me (Mixed)' : 'Made for Me',
    'Murder on the Dancefloor (Sped Up)' : 'Murder on the Dancefloor',
    'PROVENZA (Mixed)' : 'PROVENZA',
    'What Was I Made For? (Mixed)' : 'What Was I Made For?',
    'BIG GIRLS DONT CRY (workout mix)' :  'BIG GIRLS DONT CRY (workout mix)' 
}

# %%
songs_data['track_name'] = songs_data['track_name'].replace(replacement_dict)

# %%
##apply get_lyrics() to the data

songs_data['lyrics'] = [
    get_lyrics(row['track_name'], row['artist'], genius_access_token)
    for idx, row in songs_data.iterrows()
    if not print(f"Processing row {idx + 1}: {row['track_name']} by {row['artist']}")
]
# Out:
# Processing row 1: TAKI TA TRIBALERO (feat. DJ Erandes) by DJ Mecca
# Processing row 2: Montagem Mysterious Game by LXNGVX
# Processing row 3: Dumptruck by Kinfolk Thugs
# Processing row 4: Old Future by Koday Jackson
# Processing row 5: Little Life by Cordelia
# Processing row 6: A Sky Full of Stars (Live at the Royal Albert Hall, London) by Coldplay
# Processing row 7: How To Never Stop Being Sad by dandelion hands
# Processing row 8: How To Press a Pill by Punchmade Dev
# Processing row 9: CARNIVAL (feat. Playboi Carti) by ¥$, Kanye West, Ty Dolla $ign & Rich The Kid
# Processing row 10: yes, and by Ariana Grande
# Processing row 11: We Are the People (Burns Remix) by Empire of the Sun
# Processing row 12: Oh No by Lil Lucky
# Processing row 13: Blooket Freestyle Beat by cj icyy
# Processing row 14: Hot X So Much Hype by Tre Savage
# Processing row 15: I Love You by SINGHSANGER MALVINDER
# Processing row 16: Ribs by Lorde
# Processing row 17: Grey by Yung Filly
# Processing row 18: Untitled #13 (Super Slowed) by glwzbll
# Processing row 19: ICEWHORE! (slowed) by Lumi Athena
# Processing row 20: (Did Somebody Say) Just Eat by Katy Perry
# Processing row 21: Bow Bow Bow (F My Baby Dad) by Sexyy Red
# Processing row 22: Cupid's Chokehold (Featuring Patrick Stump) by Gym Class Heroes
# Processing row 23: New Home (Slowed) by Austin Farwell
# Processing row 24: What You Won't Do for Love by Bobby Caldwell
# Processing row 25: Notun Notun Payer Gulo by Khurshid Alam
# Processing row 26: Murder On the Dancefloor by Sophie Ellis-Bextor
# Processing row 27: Plan by Maxximusa
# Processing row 28: Sweetest Pie (David Guetta Dance Remix Extended) by Megan Thee Stallion, Dua Lipa & David Guetta
# Processing row 29: First Love by Oscar Ortiz & Edgardo Nuñez
# Processing row 30: Goth by Sidewalks and Skeletons
# Processing row 200: BELLAKEO by Peso Pluma & Anitta
# Processing row 201: Bella by Morrow Music
# Processing row 202: The Cat From Ipanema by j1gggs
# Processing row 203: You Don't Own Me (feat. G-Eazy) by SAYGRACE
# Processing row 204: Saturn by SZA
# Processing row 205: Adagio for Strings, Op. 11 by André Previn & Лондонский Симфонический Оркестр
# Processing row 206: Emotional by Bang Nono
# Processing row 207: I Don't Mind (feat. Juicy J) by USHER
# Processing row 208: The Cat From Ipanema by j1gggs
# Processing row 209: In The Heat Of July by Noah Kahan
# Processing row 210: Shoota (feat. Lil Uzi Vert) by Playboi Carti
# Processing row 211: CARNIVAL (feat. Playboi Carti) by ¥$, Kanye West, Ty Dolla $ign & Rich The Kid
# Processing row 212: West Coast by Lana Del Rey
# Processing row 213: Sevirem Tekce by Maqa Javadoff
# Processing row 214: How I Love Being a Woman 6 by R.m.y
# Processing row 215: September by Sparky Deathcap
# Processing row 216: Waja by Victor Beatrd
# Processing row 217: NARCISSISTIC PERSONALITY DISORDER by Odetari
# Processing row 218: Since U Been Gone by Kelly Clarkson
# Processing row 219: Made for Me by Muni Long
# Processing row 220: HOOLIGANG by Joey Valence & Brae
# Processing row 221: Ringht by Dj viti
# Processing row 222: Juega by Omar Santana
# Processing row 223: Dance The Night (Mixed) by Dua Lipa
# Processing row 224: Vox Tune by Alvin Remix
# Processing row 225: Baby (feat. Ludacris) by Justin Bieber
# Processing row 226: หลวงพี่แจ๊ส 4G (From "ภาพยนตร์เรื่องหลวงพี่แจ๊ส 4G") by ผดุง ทรงแสง (แจ๊ส)
# Processing row 227: My Boo by USHER & Alicia Keys
# Processing row 228: Copines by Aya Nakamura
# Processing row 229: SAVIOR Freestyle (feat. Lil Tidy) by Ace Mercy
# Processing row 230: redrum (Mixed) by 21 Savage
# Processing row 231: Little Life by Cordelia
# Processing row 232: Every 1's a Winner by Hot Chocolate
# Processing row 233: Interview (Interlude) by Sampleverse
# Processing row 234: Tiktok by Official Squeeze
# Processing row 235: Donk by Beyoncé
# Processing row 236: CLEARED - Remix by Lilithzplug
# Processing row 237: GODMODE.wav by Kiraw
# Processing row 238: Devil Game by Nevori Darlano
# Processing row 239: Recognize (feat. Drake) by PARTYNEXTDOOR
# Processing row 240: Lil Boo Thang (Mixed) by Paul Russell
# Processing row 241: Me Dejaste Ir by Jay Maury
# Processing row 242: Anxious Alta by Nevori Darlano
# Processing row 243: Friends In Low Places by Enkh-Erdene
# Processing row 244: Dumptruck by Kinfolk Thugs
# Processing row 245: Habits (Stay High) by Tove Lo
# Processing row 246: Keepin' IT CUTE by Lani Love
# Processing row 247: BELLAKEO by Peso Pluma & Anitta
# Processing row 248: Ashi Ashi by 6YNTHMANE & RXDXVIL
# Processing row 249: Compete by Sdot Go & Sha GZ & Jay Hound
# Processing row 250: Moonlight by king caspa
# Processing row 251: redrum (Mixed) by 21 Savage
# Processing row 252: Traditionnel musette by Maurice Larcange
# Processing row 253: Ain't No Mountain High Enough (feat. Dionne Bromfield) [Radio Edit] by Freischwimmer
# Processing row 254: Merry Go Round of Life (Old Piano) by Xakei
# Processing row 255: Leni by Crystal Castles
# Processing row 256: Safe and Sound by Capital Cities
# Processing row 257: RAHHHH (sped up) by Alt!
# Processing row 486: Mother Would B Proud by Yeuh GIN
# Processing row 487: Orquestra Maldita by TRASHXRL & Mc Delux
# Processing row 488: Rich by City Girls
# Processing row 489: Je Te Laisserai Des Mots by Patrick Watson
# Processing row 490: Donk by Beyoncé
# Processing row 491: Me Dejaste Ir by Jay Maury
# Processing row 492: Age On the Clock by Paid Actors
# Processing row 493: Ay.Makarena by JMRodriguez
# Processing row 494: หลวงพี่แจ๊ส 4G (From "ภาพยนตร์เรื่องหลวงพี่แจ๊ส 4G") by ผดุง ทรงแสง (แจ๊ส)
# Processing row 495: Is It a Crime by Sade
# Processing row 496: Flowers (Mixed) by Miley Cyrus
# Processing row 497: I Bet on Losing Dogs by Mitski
# Processing row 498: Positif by Mr. Oizo
# Processing row 499: The Way I Are by Timbaland, Keri Hilson & D.O.E.
# Processing row 500: Deli (spanish mix) by lil guero
# Processing row 501: Dummy by DummyTheKid
# Processing row 502: Iam natural by Angel Amedro
# Processing row 503: Eenie Meenie by Sean Kingston & Justin Bieber
# Processing row 504: The Night We Met by Lord Huron
# Processing row 505: Enamorado De Ti by los temerario
# Processing row 506: หลวงพี่แจ๊ส 4G (From "ภาพยนตร์เรื่องหลวงพี่แจ๊ส 4G") by ผดุง ทรงแสง (แจ๊ส)
# Processing row 507: Show Me How by Men I Trust
# Processing row 508: yes, and by Ariana Grande
# Processing row 509: Funny by Gold-Tiger
# Processing row 510: Work from Home (feat. Ty Dolla $ign) by Fifth Harmony

# %%
songs_data['lyrics']
# Out:
# 0                                       Lyrics not found
# 1                           This song is an instrumental
# 2      [Intro]\nAh-where they at?\n(K-K-K-Kin Folk Th...
# 3                                       Lyrics not found
# 4      [Verse 1]\nHow would you have me described?\nW...
#                              ...
# 505                                     Lyrics not found
# 506    [Verse 1]\nShow me how you care\nTell me how y...
# 507    [Verse 1]\nIn case you haven't noticed\nWell, ...
# 508                                     Lyrics not found
# 509    [Verse 1: Camila]\nI ain't worried about nothi...
# Name: lyrics, Length: 510, dtype: object

# %%
no_lyrics_found = songs_data[songs_data['lyrics'] == "Lyrics not found"]
no_lyrics_found = no_lyrics_found.iloc[:, 1:3]

if not no_lyrics_found.empty:
    print("Rows with no lyrics found:")
    print(no_lyrics_found)
else:
    print("Lyrics were found for all songs.")
# Out:
# Rows with no lyrics found:
#                                             track_name              artist
# 0                 TAKI TA TRIBALERO (feat. DJ Erandes)            DJ Mecca
# 3                                           Old Future       Koday Jackson
# 11                                               Oh No           Lil Lucky
# 12                              Blooket Freestyle Beat             cj icyy
# 13                                  Hot X So Much Hype          Tre Savage
# ..                                                 ...                 ...
# 500                                              Dummy         DummyTheKid
# 501                                        Iam natural        Angel Amedro
# 504                                    Enamorado De Ti       los temerario
# 505  หลวงพี่แจ๊ส 4G (From "ภาพยนตร์เรื่องหลวงพี่แจ๊...  ผดุง ทรงแสง (แจ๊ส)
# 508                                              Funny          Gold-Tiger
#
# [255 rows x 2 columns]

# %%
no_lyrics_found_unique = no_lyrics_found.drop_duplicates()

# %%
no_lyrics_found_unique
no_lyrics_found_unique.to_csv('no_lyrics_found_unique.csv', index=False)

# %%
no_lyrics_found.shape
# Out:
# (255, 2)

# %%
get_lyrics('BIG GIRLS DONT CRY', 'Toby Gad & Victoria Justice', genius_access_token)
# Out:
# 'Lyrics not found'
